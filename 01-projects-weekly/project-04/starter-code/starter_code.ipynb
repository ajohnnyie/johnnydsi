# %% [markdown]
# # Web Scraping for Indeed.com & Predicting Salaries

# %% [markdown]
# In this project, we will practice two major skills: collecting data by scraping a website and then building a binary predictor with Logistic Regression.
#
# We are going to collect salary information on data science jobs in a variety of markets. Then using the location, title and summary of the job we will attempt to predict the salary of the job. For job posting sites, this would be extraordinarily useful. While most listings DO NOT come with salary information (as you will see in this exercise), being to able extrapolate or predict the expected salaries from other listings can help guide negotiations.
#
# Normally, we could use regression for this task; however, we will convert this problem into classification and use Logistic Regression.
#
# - Question: Why would we want this to be a classification problem?
# - Answer: While more precision may be better, there is a fair amount of natural variance in job salaries - predicting a range be may be useful.
#
# Therefore, the first part of the assignment will be focused on scraping Indeed.com. In the second, we'll focus on using listings with salary information to build a model and predict additional salaries.

# %% [markdown]
# ### Scraping job listings from Indeed.com

# %% [markdown]
# We will be scraping job listings from Indeed.com using BeautifulSoup. Luckily, Indeed.com is a simple text page where we can easily find relevant entries.
#
# First, look at the source of an Indeed.com page: (http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10")
#
# Notice, each job listing is underneath a `div` tag with a class name of `result`. We can use BeautifulSoup to extract those.

# %% [markdown]
# #### Setup a request (using `requests`) to the URL below. Use BeautifulSoup to parse the page and extract all results (HINT: Look for div tags with class name result)

# %%
URL = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start="

# %%
import pandas as pd
import requests
import bs4
from bs4 import BeautifulSoup
import urllib2

# %%
## YOUR CODE HERE


location = []
company = []
summary =[]
title=[]


def extract_location_from_result(result):
        for i in result:
            location.append(i.find ("span", {"class": "location"}).text)
        return location
def extract_company_from_result(result):
        for i in result:
            company.append(i.find ("span", {"class": "company"}).text.strip())
        return company
def extract_summary_from_result(result):
        for i in result:
            summary.append(i.find ("span", {"class": "summary"}).text.strip())
        return summary
def extract_title_from_result(result):
        for i in result:
            title.append(i.find("a", {"class": "turnstileLink"}).text.strip())
        return title

# %%
for p in [1,2,3,4,5,6,7]:
    page= urllib2.urlopen(URL+str(p*10))
    soup = BeautifulSoup(page.read())
    r  = requests.get(URL)
    data = r.text
    soup = BeautifulSoup(data)
    letters = soup.find_all("div", {"class": " row result"})
    for letter in letters:
        print letter.prettify()
        
    extract_location_from_result(letters)    
    extract_company_from_result(letters)
    extract_summary_from_result(letters)
    extract_title_from_result(letters)
# Out:
# <div class=" row result" data-jk="e51628a2e0e2b6b1" data-tn-component="organicJob" id="p_e51628a2e0e2b6b1" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_e51628a2e0e2b6b1">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=e51628a2e0e2b6b1&amp;fccid=086cb533b5438773" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[0],true,0);" onmousedown="return rclk(this,jobmap[0],0);" rel="nofollow" target="_blank" title="Data Scientist">
#    <b>
#     Data
#    </b>
#    <b>
#     Scientist
#    </b>
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    Komodo Health
#   </span>
#  </span>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       Experience working with proprietary secondary
#       <b>
#        data
#       </b>
#       including medical / pharmacy claims, prescription
#       <b>
#        data
#       </b>
#       , sales
#       <b>
#        data
#       </b>
#       , and longitudinal patient-level
#       <b>
#        data
#       </b>
#       ....
#      </span>
#     </div>
#     <div class="iaP">
#      <span class="iaLabel">
#       Easily apply
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="date">
#        5 days ago
#       </span>
#       <span class="tt_set" id="tt_set_0">
#        -
#        <span class="savelink2" id="savelink2_e51628a2e0e2b6b1">
#         <a class="sl resultLink save-job-link" href="#" id="sj_e51628a2e0e2b6b1" onclick="changeJobState('e51628a2e0e2b6b1', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('e51628a2e0e2b6b1', 0, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_0" onclick="toggleMoreLinks('e51628a2e0e2b6b1'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_e51628a2e0e2b6b1" style="display:none;">
#       </div>
#       <script>
#        window['result_e51628a2e0e2b6b1'] = {"showSource": false, "source": "Komodo Health", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "5 days ago","jobKey": "e51628a2e0e2b6b1", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 0, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_0" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('e51628a2e0e2b6b1'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_0">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-Komodo-Health-l-New-York,-NY-jobs.html" rel="nofollow">
#            Komodo Health jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">
#            Data Scientist salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#           -
#           <a href="/forum/cmp/Komodo-Health.html">
#            Komodo Health
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# <div class=" row result" data-jk="4409120c119aaad4" data-tn-component="organicJob" id="p_4409120c119aaad4" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_4409120c119aaad4">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=4409120c119aaad4&amp;fccid=d0a62972bb1812fd" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[1],true,0);" onmousedown="return rclk(this,jobmap[1],0);" rel="nofollow" target="_blank" title="Data Scientist">
#    <b>
#     Data
#    </b>
#    <b>
#     Scientist
#    </b>
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    <a href="/cmp/Crisis-Text-Line?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=4409120c119aaad4&amp;jcid=fb5f16a6f0391ca1" target="_blank">
#     Crisis Text Line
#    </a>
#   </span>
#  </span>
#  -
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Crisis-Text-Line/reviews?jcid=fb5f16a6f0391ca1" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist&amp;fromjk=4409120c119aaad4');" target="_blank" title="Crisis Text Line reviews">
#   <span class="ratingNumber" style="font-size: 13px; vertical-align: baseline;">
#    5.0
#   </span>
#   <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;">
#    <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 60.0px;">
#     <!-- -->
#    </span>
#   </span>
#   <span class="slNoUnderline">
#    3 reviews
#   </span>
#  </a>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       Chief
#       <b>
#        Data
#       </b>
#       <b>
#        Scientist
#       </b>
#       . The
#       <b>
#        Data
#       </b>
#       Scientist's role at Crisis Text Line is to support staff in making smarter decisions through
#       <b>
#        data
#       </b>
#       ....
#      </span>
#     </div>
#     <div class="iaP">
#      <span class="iaLabel">
#       Easily apply
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="date">
#        4 days ago
#       </span>
#       <span class="tt_set" id="tt_set_1">
#        -
#        <span class="savelink2" id="savelink2_4409120c119aaad4">
#         <a class="sl resultLink save-job-link" href="#" id="sj_4409120c119aaad4" onclick="changeJobState('4409120c119aaad4', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('4409120c119aaad4', 1, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_1" onclick="toggleMoreLinks('4409120c119aaad4'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_4409120c119aaad4" style="display:none;">
#       </div>
#       <script>
#        window['result_4409120c119aaad4'] = {"showSource": false, "source": "Crisis Text Line", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "4 days ago","jobKey": "4409120c119aaad4", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 1, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_1" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('4409120c119aaad4'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_1">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-Crisis-Text-Line-l-New-York,-NY-jobs.html" rel="nofollow">
#            Crisis Text Line jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">
#            Data Scientist salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Learn more about working at
#           <a href="/cmp/Crisis-Text-Line?fromjk=4409120c119aaad4&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=fb5f16a6f0391ca1">
#            Crisis Text Line
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#           -
#           <a href="/forum/cmp/Crisis-Text-Line.html">
#            Crisis Text Line
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# <div class=" row result" data-jk="014b8a78dbafbeee" data-tn-component="organicJob" id="p_014b8a78dbafbeee" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_014b8a78dbafbeee">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=014b8a78dbafbeee&amp;fccid=3de83442785d5fca" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[2],true,0);" onmousedown="return rclk(this,jobmap[2],0);" rel="nofollow" target="_blank" title="GrubHub - Data Scientist">
#    GrubHub -
#    <b>
#     Data
#    </b>
#    <b>
#     Scientist
#    </b>
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    Illinois Technology Association
#   </span>
#  </span>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       Grow our real-time internal
#       <b>
#        data
#       </b>
#       intelligence API. Informal understanding of
#       <b>
#        data
#       </b>
#       structures and computational complexity....
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="date">
#        3 days ago
#       </span>
#       <span class="tt_set" id="tt_set_2">
#        -
#        <span class="savelink2" id="savelink2_014b8a78dbafbeee">
#         <a class="sl resultLink save-job-link" href="#" id="sj_014b8a78dbafbeee" onclick="changeJobState('014b8a78dbafbeee', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('014b8a78dbafbeee', 2, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_2" onclick="toggleMoreLinks('014b8a78dbafbeee'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_014b8a78dbafbeee" style="display:none;">
#       </div>
#       <script>
#        window['result_014b8a78dbafbeee'] = {"showSource": false, "source": "Illinois Technology Association", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "3 days ago","jobKey": "014b8a78dbafbeee", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 2, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_2" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('014b8a78dbafbeee'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_2">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-Illinois-Technology-Association-l-New-York,-NY-jobs.html" rel="nofollow">
#            Illinois Technology Association jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Grubhub&amp;l1=New+York%2C+NY">
#            Grubhub salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Learn more about working at
#           <a href="/cmp/Illinois-Technology-Association?fromjk=014b8a78dbafbeee&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=3de83442785d5fca">
#            Illinois Technology Association
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#           -
#           <a href="/forum/cmp/Illinois-Technology-Association.html">
#            Illinois Technology Association
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# <div class=" row result" data-jk="c0fb1fe98b72b8f8" data-tn-component="organicJob" id="p_c0fb1fe98b72b8f8" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_c0fb1fe98b72b8f8">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=c0fb1fe98b72b8f8&amp;fccid=3c371b712ace44cf" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[3],true,0);" onmousedown="return rclk(this,jobmap[3],0);" rel="nofollow" target="_blank" title="Data Scientist">
#    <b>
#     Data
#    </b>
#    <b>
#     Scientist
#    </b>
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    <a href="/cmp/Dish?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=c0fb1fe98b72b8f8&amp;jcid=9d6f5c1f25e62b5d" target="_blank">
#     DISH Network
#    </a>
#   </span>
#  </span>
#  -
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Dish/reviews?jcid=9d6f5c1f25e62b5d" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist&amp;fromjk=c0fb1fe98b72b8f8');" target="_blank" title="Dish Network reviews">
#   <span class="ratingNumber" style="font-size: 13px; vertical-align: baseline;">
#    3.3
#   </span>
#   <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;">
#    <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 40.8px;">
#     <!-- -->
#    </span>
#   </span>
#   <span class="slNoUnderline">
#    1,908 reviews
#   </span>
#  </a>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       A successful
#       <b>
#        Data
#       </b>
#       <b>
#        Scientist
#       </b>
#       will have the following:. Developing critical analytics using key DISH
#       <b>
#        data
#       </b>
#       sources including the viewer measurement
#       <b>
#        data
#       </b>
#       and...
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="result-link-source">
#        DISH
#       </span>
#       -
#       <span class="date">
#        6 days ago
#       </span>
#       <span class="tt_set" id="tt_set_3">
#        -
#        <span class="savelink2" id="savelink2_c0fb1fe98b72b8f8">
#         <a class="sl resultLink save-job-link" href="#" id="sj_c0fb1fe98b72b8f8" onclick="changeJobState('c0fb1fe98b72b8f8', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('c0fb1fe98b72b8f8', 3, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_3" onclick="toggleMoreLinks('c0fb1fe98b72b8f8'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_c0fb1fe98b72b8f8" style="display:none;">
#       </div>
#       <script>
#        window['result_c0fb1fe98b72b8f8'] = {"showSource": true, "source": "DISH", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "6 days ago","jobKey": "c0fb1fe98b72b8f8", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 3, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_3" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('c0fb1fe98b72b8f8'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_3">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-Dish-Network-l-New-York,-NY-jobs.html" rel="nofollow">
#            DISH Network jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">
#            Data Scientist salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Learn more about working at
#           <a href="/cmp/Dish?fromjk=c0fb1fe98b72b8f8&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=9d6f5c1f25e62b5d">
#            Dish Network
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#           -
#           <a href="/forum/cmp/Dish.html">
#            DISH
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# <div class=" row result" data-jk="53839cd3265499b6" data-tn-component="organicJob" id="p_53839cd3265499b6" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_53839cd3265499b6">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=53839cd3265499b6&amp;fccid=1d8e31f3f2dffe07" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[4],true,0);" onmousedown="return rclk(this,jobmap[4],0);" rel="nofollow" target="_blank" title="Data Scientist">
#    <b>
#     Data
#    </b>
#    <b>
#     Scientist
#    </b>
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    DataKind
#   </span>
#  </span>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       A mid-career
#       <b>
#        data
#       </b>
#       <b>
#        scientist
#       </b>
#       - You have a successful track record leading and executing a broad range of
#       <b>
#        data
#       </b>
#       science projects spanning the entire project...
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="result-link-source">
#        Omidyar Networks
#       </span>
#       -
#       <span class="date">
#        4 days ago
#       </span>
#       <span class="tt_set" id="tt_set_4">
#        -
#        <span class="savelink2" id="savelink2_53839cd3265499b6">
#         <a class="sl resultLink save-job-link" href="#" id="sj_53839cd3265499b6" onclick="changeJobState('53839cd3265499b6', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('53839cd3265499b6', 4, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_4" onclick="toggleMoreLinks('53839cd3265499b6'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_53839cd3265499b6" style="display:none;">
#       </div>
#       <script>
#        window['result_53839cd3265499b6'] = {"showSource": true, "source": "Omidyar Networks", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "4 days ago","jobKey": "53839cd3265499b6", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 4, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_4" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('53839cd3265499b6'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_4">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-Datakind-l-New-York,-NY-jobs.html" rel="nofollow">
#            DataKind jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">
#            Data Scientist salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#           -
#           <a href="/forum/cmp/Datakind.html">
#            DataKind
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# <div class=" row result" data-jk="77be4fe06c2eb4a5" data-tn-component="organicJob" id="p_77be4fe06c2eb4a5" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_77be4fe06c2eb4a5">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=77be4fe06c2eb4a5&amp;fccid=c618ba0d5e55039b" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[5],true,0);" onmousedown="return rclk(this,jobmap[5],0);" rel="nofollow" target="_blank" title="Data Scientist">
#    <b>
#     Data
#    </b>
#    <b>
#     Scientist
#    </b>
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    Paperless Post
#   </span>
#  </span>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       Build production systems to collect and process
#       <b>
#        data
#       </b>
#       . Analyze the
#       <b>
#        data
#       </b>
#       we collect to generate important insights....
#      </span>
#     </div>
#     <div class="iaP">
#      <span class="iaLabel">
#       Easily apply
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="date">
#        4 days ago
#       </span>
#       <span class="tt_set" id="tt_set_5">
#        -
#        <span class="savelink2" id="savelink2_77be4fe06c2eb4a5">
#         <a class="sl resultLink save-job-link" href="#" id="sj_77be4fe06c2eb4a5" onclick="changeJobState('77be4fe06c2eb4a5', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('77be4fe06c2eb4a5', 5, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_5" onclick="toggleMoreLinks('77be4fe06c2eb4a5'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_77be4fe06c2eb4a5" style="display:none;">
#       </div>
#       <script>
#        window['result_77be4fe06c2eb4a5'] = {"showSource": false, "source": "Paperless Post", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "4 days ago","jobKey": "77be4fe06c2eb4a5", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 5, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_5" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('77be4fe06c2eb4a5'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_5">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-Paperless-Post-l-New-York,-NY-jobs.html" rel="nofollow">
#            Paperless Post jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">
#            Data Scientist salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Learn more about working at
#           <a href="/cmp/Paperless-Post?fromjk=77be4fe06c2eb4a5&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=c618ba0d5e55039b">
#            Paperless Post
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#           -
#           <a href="/forum/cmp/Paperless-Post.html">
#            Paperless Post
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# <div class=" row result" data-jk="6ca932c2af4750af" data-tn-component="organicJob" id="p_6ca932c2af4750af" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_6ca932c2af4750af">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/cmp/ShopKeep/jobs/Data-Scientist-6ca932c2af4750af?r=1&amp;fccid=11811b52a7138086" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[6],true,0);" onmousedown="return rclk(this,jobmap[6],0);" rel="nofollow" target="_blank" title="Data Scientist">
#    <b>
#     Data
#    </b>
#    <b>
#     Scientist
#    </b>
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    <a href="/cmp/Shopkeep?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=6ca932c2af4750af&amp;jcid=11811b52a7138086" target="_blank">
#     ShopKeep
#    </a>
#   </span>
#  </span>
#  -
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Shopkeep/reviews?jcid=11811b52a7138086" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist&amp;fromjk=6ca932c2af4750af');" target="_blank" title="Shopkeep reviews">
#   <span class="ratingNumber" style="font-size: 13px; vertical-align: baseline;">
#    3.8
#   </span>
#   <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;">
#    <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 43.8px;">
#     <!-- -->
#    </span>
#   </span>
#   <span class="slNoUnderline">
#    4 reviews
#   </span>
#  </a>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY 10013
#     <span style="font-size: smaller">
#      (Tribeca area)
#     </span>
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       We have a mature
#       <b>
#        data
#       </b>
#       infrastructure, and we’d like someone to interrogate this
#       <b>
#        data
#       </b>
#       relentlessly.
#       <b>
#        Data
#       </b>
#       visualization / exploration tools (especially Looker)....
#      </span>
#     </div>
#     <div class="iaP">
#      <span class="iaLabel">
#       Easily apply
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="date">
#        7 days ago
#       </span>
#       <span class="tt_set" id="tt_set_6">
#        -
#        <span class="savelink2" id="savelink2_6ca932c2af4750af">
#         <a class="sl resultLink save-job-link" href="#" id="sj_6ca932c2af4750af" onclick="changeJobState('6ca932c2af4750af', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('6ca932c2af4750af', 6, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_6" onclick="toggleMoreLinks('6ca932c2af4750af'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_6ca932c2af4750af" style="display:none;">
#       </div>
#       <script>
#        window['result_6ca932c2af4750af'] = {"showSource": false, "source": "Indeed", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "7 days ago","jobKey": "6ca932c2af4750af", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 6, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_6" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('6ca932c2af4750af'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_6">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-Shopkeep-l-New-York,-NY-jobs.html" rel="nofollow">
#            ShopKeep jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">
#            Data Scientist salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Learn more about working at
#           <a href="/cmp/Shopkeep?fromjk=6ca932c2af4750af&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=11811b52a7138086">
#            Shopkeep
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#           -
#           <a href="/forum/cmp/Shopkeep.html">
#            ShopKeep
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# <div class=" row result" data-jk="5b4cfc8994a61b41" data-tn-component="organicJob" id="p_5b4cfc8994a61b41" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_5b4cfc8994a61b41">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=5b4cfc8994a61b41&amp;fccid=ea25315ee9da22e5" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[7],true,0);" onmousedown="return rclk(this,jobmap[7],0);" rel="nofollow" target="_blank" title="Data Scientist">
#    <b>
#     Data
#    </b>
#    <b>
#     Scientist
#    </b>
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    <a href="/cmp/Comcast?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=5b4cfc8994a61b41&amp;jcid=ea25315ee9da22e5" target="_blank">
#     Comcast
#    </a>
#   </span>
#  </span>
#  -
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Comcast/reviews?jcid=ea25315ee9da22e5" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist&amp;fromjk=5b4cfc8994a61b41');" target="_blank" title="Comcast reviews">
#   <span class="ratingNumber" style="font-size: 13px; vertical-align: baseline;">
#    3.8
#   </span>
#   <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;">
#    <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 43.8px;">
#     <!-- -->
#    </span>
#   </span>
#   <span class="slNoUnderline">
#    5,987 reviews
#   </span>
#  </a>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       Visible World is the leading provider of targeted TV advertising solutions. Our technology makes television advertising inventory more valuable for inventory
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="date">
#        5 days ago
#       </span>
#       <span class="tt_set" id="tt_set_7">
#        -
#        <span class="savelink2" id="savelink2_5b4cfc8994a61b41">
#         <a class="sl resultLink save-job-link" href="#" id="sj_5b4cfc8994a61b41" onclick="changeJobState('5b4cfc8994a61b41', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('5b4cfc8994a61b41', 7, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_7" onclick="toggleMoreLinks('5b4cfc8994a61b41'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_5b4cfc8994a61b41" style="display:none;">
#       </div>
#       <script>
#        window['result_5b4cfc8994a61b41'] = {"showSource": false, "source": "Comcast", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "5 days ago","jobKey": "5b4cfc8994a61b41", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 7, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_7" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('5b4cfc8994a61b41'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_7">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-Comcast-l-New-York,-NY-jobs.html" rel="nofollow">
#            Comcast jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">
#            Data Scientist salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Learn more about working at
#           <a href="/cmp/Comcast?fromjk=5b4cfc8994a61b41&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=ea25315ee9da22e5">
#            Comcast
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#           -
#           <a href="/forum/cmp/Comcast.html">
#            Comcast
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# <div class=" row result" data-jk="30c228790352e62c" data-tn-component="organicJob" id="p_30c228790352e62c" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_30c228790352e62c">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=30c228790352e62c&amp;fccid=c63a4b95712b07d4" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[8],true,0);" onmousedown="return rclk(this,jobmap[8],0);" rel="nofollow" target="_blank" title="Data Scientist">
#    <b>
#     Data
#    </b>
#    <b>
#     Scientist
#    </b>
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    Tapad
#   </span>
#  </span>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       Tapad is looking for an experienced
#       <b>
#        Data
#       </b>
#       <b>
#        Scientist
#       </b>
#       to join our Engineering team. The
#       <b>
#        Data
#       </b>
#       <b>
#        Scientist
#       </b>
#       will work on expanding and developing the core of our...
#      </span>
#     </div>
#     <div class="iaP">
#      <span class="iaLabel">
#       Easily apply
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="date">
#        8 days ago
#       </span>
#       <span class="tt_set" id="tt_set_8">
#        -
#        <span class="savelink2" id="savelink2_30c228790352e62c">
#         <a class="sl resultLink save-job-link" href="#" id="sj_30c228790352e62c" onclick="changeJobState('30c228790352e62c', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('30c228790352e62c', 8, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_8" onclick="toggleMoreLinks('30c228790352e62c'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_30c228790352e62c" style="display:none;">
#       </div>
#       <script>
#        window['result_30c228790352e62c'] = {"showSource": false, "source": "Tapad", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "8 days ago","jobKey": "30c228790352e62c", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 8, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_8" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('30c228790352e62c'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_8">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-Tapad-l-New-York,-NY-jobs.html" rel="nofollow">
#            Tapad jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">
#            Data Scientist salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#           -
#           <a href="/forum/cmp/Tapad.html">
#            Tapad
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-23ea717bf53e> in <module>()
#      13     extract_company_from_result(letters)
#      14     extract_summary_from_result(letters)
# ---> 15     extract_title_from_result(letters)
#      16
#
# <ipython-input-81-4d71322c5f48> in extract_title_from_result(result)
#      22 def extract_title_from_result(result):
#      23         for i in result:
# ---> 24             title.append(i.find("span", {"class": "turnstileLink"}).text.strip())
#      25         return title
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
title
# Out:
# []

# %% [markdown]
# ### Write 4 functions to extract each item: location, company, job, and salary.
#
# example:
# ```python
# def extract_location_from_result(result):
#     return result.find ...
# ```
#
#
# - Make sure these functions are robust and can handle cases where the data/field may not be available.
# - Test the functions on the results above

# %%
page= urllib2.urlopen(URL+str(1*10))
soup = BeautifulSoup(page.read())
r  = requests.get(URL)
data = r.text
soup = BeautifulSoup(data)
letters = soup.find_all("div", {"class": " row result"})
for letter in letters:
    print letter.prettify()

## YOUR CODE HERE
def extract_location_from_result(result):
    location = []
    for i in result:
        location.append(i.find ("span", {"class": "location"}).text)
    return location
def extract_company_from_result(result):
    company = []
    for i in result:
        company.append(i.find ("span", {"class": "company"}).text.strip())
    return company
def extract_summary_from_result(result):
    summary =[]
    for i in result:
        summary.append(i.find ("span", {"class": "summary"}).text.strip())
    return summary

def extract_title_from_result(result):
    title=[]
    for i in result:
        title.append(i.find("span", {"class": "turnstileLink"}).text.strip())
    return title

location = extract_location_from_result(letters)
company = extract_company_from_result(letters)
summary = extract_summary_from_result(letters)
#print location
#print company
#print summary
print title
# Out:
# <div class=" row result" data-jk="e51628a2e0e2b6b1" data-tn-component="organicJob" id="p_e51628a2e0e2b6b1" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_e51628a2e0e2b6b1">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=e51628a2e0e2b6b1&amp;fccid=086cb533b5438773" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[0],true,0);" onmousedown="return rclk(this,jobmap[0],0);" rel="nofollow" target="_blank" title="Data Scientist">
#    <b>
#     Data
#    </b>
#    <b>
#     Scientist
#    </b>
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    Komodo Health
#   </span>
#  </span>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       Experience working with proprietary secondary
#       <b>
#        data
#       </b>
#       including medical / pharmacy claims, prescription
#       <b>
#        data
#       </b>
#       , sales
#       <b>
#        data
#       </b>
#       , and longitudinal patient-level
#       <b>
#        data
#       </b>
#       ....
#      </span>
#     </div>
#     <div class="iaP">
#      <span class="iaLabel">
#       Easily apply
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="date">
#        5 days ago
#       </span>
#       <span class="tt_set" id="tt_set_0">
#        -
#        <span class="savelink2" id="savelink2_e51628a2e0e2b6b1">
#         <a class="sl resultLink save-job-link" href="#" id="sj_e51628a2e0e2b6b1" onclick="changeJobState('e51628a2e0e2b6b1', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('e51628a2e0e2b6b1', 0, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_0" onclick="toggleMoreLinks('e51628a2e0e2b6b1'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_e51628a2e0e2b6b1" style="display:none;">
#       </div>
#       <script>
#        window['result_e51628a2e0e2b6b1'] = {"showSource": false, "source": "Komodo Health", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "5 days ago","jobKey": "e51628a2e0e2b6b1", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 0, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_0" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('e51628a2e0e2b6b1'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_0">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-Komodo-Health-l-New-York,-NY-jobs.html" rel="nofollow">
#            Komodo Health jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">
#            Data Scientist salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#           -
#           <a href="/forum/cmp/Komodo-Health.html">
#            Komodo Health
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# <div class=" row result" data-jk="4409120c119aaad4" data-tn-component="organicJob" id="p_4409120c119aaad4" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_4409120c119aaad4">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=4409120c119aaad4&amp;fccid=d0a62972bb1812fd" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[1],true,0);" onmousedown="return rclk(this,jobmap[1],0);" rel="nofollow" target="_blank" title="Data Scientist">
#    <b>
#     Data
#    </b>
#    <b>
#     Scientist
#    </b>
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    <a href="/cmp/Crisis-Text-Line?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=4409120c119aaad4&amp;jcid=fb5f16a6f0391ca1" target="_blank">
#     Crisis Text Line
#    </a>
#   </span>
#  </span>
#  -
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Crisis-Text-Line/reviews?jcid=fb5f16a6f0391ca1" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist&amp;fromjk=4409120c119aaad4');" target="_blank" title="Crisis Text Line reviews">
#   <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;">
#    <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 60.0px;">
#     <!-- -->
#    </span>
#   </span>
#   <span class="slNoUnderline">
#    3 reviews
#   </span>
#  </a>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       Chief
#       <b>
#        Data
#       </b>
#       <b>
#        Scientist
#       </b>
#       . The
#       <b>
#        Data
#       </b>
#       Scientist's role at Crisis Text Line is to support staff in making smarter decisions through
#       <b>
#        data
#       </b>
#       ....
#      </span>
#     </div>
#     <div class="iaP">
#      <span class="iaLabel">
#       Easily apply
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="date">
#        4 days ago
#       </span>
#       <span class="tt_set" id="tt_set_1">
#        -
#        <span class="savelink2" id="savelink2_4409120c119aaad4">
#         <a class="sl resultLink save-job-link" href="#" id="sj_4409120c119aaad4" onclick="changeJobState('4409120c119aaad4', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('4409120c119aaad4', 1, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_1" onclick="toggleMoreLinks('4409120c119aaad4'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_4409120c119aaad4" style="display:none;">
#       </div>
#       <script>
#        window['result_4409120c119aaad4'] = {"showSource": false, "source": "Crisis Text Line", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "4 days ago","jobKey": "4409120c119aaad4", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 1, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_1" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('4409120c119aaad4'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_1">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-Crisis-Text-Line-l-New-York,-NY-jobs.html" rel="nofollow">
#            Crisis Text Line jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">
#            Data Scientist salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Learn more about working at
#           <a href="/cmp/Crisis-Text-Line?fromjk=4409120c119aaad4&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=fb5f16a6f0391ca1">
#            Crisis Text Line
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#           -
#           <a href="/forum/cmp/Crisis-Text-Line.html">
#            Crisis Text Line
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# <div class=" row result" data-jk="014b8a78dbafbeee" data-tn-component="organicJob" id="p_014b8a78dbafbeee" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_014b8a78dbafbeee">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=014b8a78dbafbeee&amp;fccid=3de83442785d5fca" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[2],true,0);" onmousedown="return rclk(this,jobmap[2],0);" rel="nofollow" target="_blank" title="GrubHub - Data Scientist">
#    GrubHub -
#    <b>
#     Data
#    </b>
#    <b>
#     Scientist
#    </b>
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    Illinois Technology Association
#   </span>
#  </span>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       Grow our real-time internal
#       <b>
#        data
#       </b>
#       intelligence API. Informal understanding of
#       <b>
#        data
#       </b>
#       structures and computational complexity....
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="date">
#        3 days ago
#       </span>
#       <span class="tt_set" id="tt_set_2">
#        -
#        <span class="savelink2" id="savelink2_014b8a78dbafbeee">
#         <a class="sl resultLink save-job-link" href="#" id="sj_014b8a78dbafbeee" onclick="changeJobState('014b8a78dbafbeee', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('014b8a78dbafbeee', 2, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_2" onclick="toggleMoreLinks('014b8a78dbafbeee'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_014b8a78dbafbeee" style="display:none;">
#       </div>
#       <script>
#        window['result_014b8a78dbafbeee'] = {"showSource": false, "source": "Illinois Technology Association", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "3 days ago","jobKey": "014b8a78dbafbeee", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 2, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_2" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('014b8a78dbafbeee'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_2">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-Illinois-Technology-Association-l-New-York,-NY-jobs.html" rel="nofollow">
#            Illinois Technology Association jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Grubhub&amp;l1=New+York%2C+NY">
#            Grubhub salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Learn more about working at
#           <a href="/cmp/Illinois-Technology-Association?fromjk=014b8a78dbafbeee&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=3de83442785d5fca">
#            Illinois Technology Association
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#           -
#           <a href="/forum/cmp/Illinois-Technology-Association.html">
#            Illinois Technology Association
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# <div class=" row result" data-jk="c0fb1fe98b72b8f8" data-tn-component="organicJob" id="p_c0fb1fe98b72b8f8" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_c0fb1fe98b72b8f8">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=c0fb1fe98b72b8f8&amp;fccid=3c371b712ace44cf" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[3],true,0);" onmousedown="return rclk(this,jobmap[3],0);" rel="nofollow" target="_blank" title="Data Scientist">
#    <b>
#     Data
#    </b>
#    <b>
#     Scientist
#    </b>
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    <a href="/cmp/Dish?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=c0fb1fe98b72b8f8&amp;jcid=9d6f5c1f25e62b5d" target="_blank">
#     DISH Network
#    </a>
#   </span>
#  </span>
#  -
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Dish/reviews?jcid=9d6f5c1f25e62b5d" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist&amp;fromjk=c0fb1fe98b72b8f8');" target="_blank" title="Dish Network reviews">
#   <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;">
#    <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 40.8px;">
#     <!-- -->
#    </span>
#   </span>
#   <span class="slNoUnderline">
#    1,908 reviews
#   </span>
#  </a>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       A successful
#       <b>
#        Data
#       </b>
#       <b>
#        Scientist
#       </b>
#       will have the following:. Developing critical analytics using key DISH
#       <b>
#        data
#       </b>
#       sources including the viewer measurement
#       <b>
#        data
#       </b>
#       and...
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="result-link-source">
#        DISH
#       </span>
#       -
#       <span class="date">
#        6 days ago
#       </span>
#       <span class="tt_set" id="tt_set_3">
#        -
#        <span class="savelink2" id="savelink2_c0fb1fe98b72b8f8">
#         <a class="sl resultLink save-job-link" href="#" id="sj_c0fb1fe98b72b8f8" onclick="changeJobState('c0fb1fe98b72b8f8', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('c0fb1fe98b72b8f8', 3, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_3" onclick="toggleMoreLinks('c0fb1fe98b72b8f8'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_c0fb1fe98b72b8f8" style="display:none;">
#       </div>
#       <script>
#        window['result_c0fb1fe98b72b8f8'] = {"showSource": true, "source": "DISH", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "6 days ago","jobKey": "c0fb1fe98b72b8f8", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 3, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_3" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('c0fb1fe98b72b8f8'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_3">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-Dish-Network-l-New-York,-NY-jobs.html" rel="nofollow">
#            DISH Network jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">
#            Data Scientist salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Learn more about working at
#           <a href="/cmp/Dish?fromjk=c0fb1fe98b72b8f8&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=9d6f5c1f25e62b5d">
#            Dish Network
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#           -
#           <a href="/forum/cmp/Dish.html">
#            DISH
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# <div class=" row result" data-jk="53839cd3265499b6" data-tn-component="organicJob" id="p_53839cd3265499b6" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_53839cd3265499b6">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=53839cd3265499b6&amp;fccid=1d8e31f3f2dffe07" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[4],true,0);" onmousedown="return rclk(this,jobmap[4],0);" rel="nofollow" target="_blank" title="Data Scientist">
#    <b>
#     Data
#    </b>
#    <b>
#     Scientist
#    </b>
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    DataKind
#   </span>
#  </span>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       A mid-career
#       <b>
#        data
#       </b>
#       <b>
#        scientist
#       </b>
#       - You have a successful track record leading and executing a broad range of
#       <b>
#        data
#       </b>
#       science projects spanning the entire project...
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="result-link-source">
#        Omidyar Networks
#       </span>
#       -
#       <span class="date">
#        4 days ago
#       </span>
#       <span class="tt_set" id="tt_set_4">
#        -
#        <span class="savelink2" id="savelink2_53839cd3265499b6">
#         <a class="sl resultLink save-job-link" href="#" id="sj_53839cd3265499b6" onclick="changeJobState('53839cd3265499b6', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('53839cd3265499b6', 4, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_4" onclick="toggleMoreLinks('53839cd3265499b6'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_53839cd3265499b6" style="display:none;">
#       </div>
#       <script>
#        window['result_53839cd3265499b6'] = {"showSource": true, "source": "Omidyar Networks", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "4 days ago","jobKey": "53839cd3265499b6", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 4, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_4" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('53839cd3265499b6'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_4">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-Datakind-l-New-York,-NY-jobs.html" rel="nofollow">
#            DataKind jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">
#            Data Scientist salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#           -
#           <a href="/forum/cmp/Datakind.html">
#            DataKind
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# <div class=" row result" data-jk="77be4fe06c2eb4a5" data-tn-component="organicJob" id="p_77be4fe06c2eb4a5" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_77be4fe06c2eb4a5">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=77be4fe06c2eb4a5&amp;fccid=c618ba0d5e55039b" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[5],true,0);" onmousedown="return rclk(this,jobmap[5],0);" rel="nofollow" target="_blank" title="Data Scientist">
#    <b>
#     Data
#    </b>
#    <b>
#     Scientist
#    </b>
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    Paperless Post
#   </span>
#  </span>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       Build production systems to collect and process
#       <b>
#        data
#       </b>
#       . Analyze the
#       <b>
#        data
#       </b>
#       we collect to generate important insights....
#      </span>
#     </div>
#     <div class="iaP">
#      <span class="iaLabel">
#       Easily apply
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="date">
#        4 days ago
#       </span>
#       <span class="tt_set" id="tt_set_5">
#        -
#        <span class="savelink2" id="savelink2_77be4fe06c2eb4a5">
#         <a class="sl resultLink save-job-link" href="#" id="sj_77be4fe06c2eb4a5" onclick="changeJobState('77be4fe06c2eb4a5', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('77be4fe06c2eb4a5', 5, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_5" onclick="toggleMoreLinks('77be4fe06c2eb4a5'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_77be4fe06c2eb4a5" style="display:none;">
#       </div>
#       <script>
#        window['result_77be4fe06c2eb4a5'] = {"showSource": false, "source": "Paperless Post", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "4 days ago","jobKey": "77be4fe06c2eb4a5", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 5, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_5" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('77be4fe06c2eb4a5'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_5">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-Paperless-Post-l-New-York,-NY-jobs.html" rel="nofollow">
#            Paperless Post jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">
#            Data Scientist salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Learn more about working at
#           <a href="/cmp/Paperless-Post?fromjk=77be4fe06c2eb4a5&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=c618ba0d5e55039b">
#            Paperless Post
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#           -
#           <a href="/forum/cmp/Paperless-Post.html">
#            Paperless Post
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# <div class=" row result" data-jk="6ca932c2af4750af" data-tn-component="organicJob" id="p_6ca932c2af4750af" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_6ca932c2af4750af">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/cmp/ShopKeep/jobs/Data-Scientist-6ca932c2af4750af?r=1&amp;fccid=11811b52a7138086" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[6],true,0);" onmousedown="return rclk(this,jobmap[6],0);" rel="nofollow" target="_blank" title="Data Scientist">
#    <b>
#     Data
#    </b>
#    <b>
#     Scientist
#    </b>
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    <a href="/cmp/Shopkeep?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=6ca932c2af4750af&amp;jcid=11811b52a7138086" target="_blank">
#     ShopKeep
#    </a>
#   </span>
#  </span>
#  -
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Shopkeep/reviews?jcid=11811b52a7138086" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist&amp;fromjk=6ca932c2af4750af');" target="_blank" title="Shopkeep reviews">
#   <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;">
#    <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 43.8px;">
#     <!-- -->
#    </span>
#   </span>
#   <span class="slNoUnderline">
#    4 reviews
#   </span>
#  </a>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY 10013
#     <span style="font-size: smaller">
#      (Tribeca area)
#     </span>
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       We have a mature
#       <b>
#        data
#       </b>
#       infrastructure, and we’d like someone to interrogate this
#       <b>
#        data
#       </b>
#       relentlessly.
#       <b>
#        Data
#       </b>
#       visualization / exploration tools (especially Looker)....
#      </span>
#     </div>
#     <div class="iaP">
#      <span class="iaLabel">
#       Easily apply
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="date">
#        7 days ago
#       </span>
#       <span class="tt_set" id="tt_set_6">
#        -
#        <span class="savelink2" id="savelink2_6ca932c2af4750af">
#         <a class="sl resultLink save-job-link" href="#" id="sj_6ca932c2af4750af" onclick="changeJobState('6ca932c2af4750af', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('6ca932c2af4750af', 6, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_6" onclick="toggleMoreLinks('6ca932c2af4750af'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_6ca932c2af4750af" style="display:none;">
#       </div>
#       <script>
#        window['result_6ca932c2af4750af'] = {"showSource": false, "source": "Indeed", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "7 days ago","jobKey": "6ca932c2af4750af", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 6, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_6" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('6ca932c2af4750af'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_6">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-Shopkeep-l-New-York,-NY-jobs.html" rel="nofollow">
#            ShopKeep jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">
#            Data Scientist salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Learn more about working at
#           <a href="/cmp/Shopkeep?fromjk=6ca932c2af4750af&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=11811b52a7138086">
#            Shopkeep
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#           -
#           <a href="/forum/cmp/Shopkeep.html">
#            ShopKeep
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# <div class=" row result" data-jk="5b4cfc8994a61b41" data-tn-component="organicJob" id="p_5b4cfc8994a61b41" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_5b4cfc8994a61b41">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=5b4cfc8994a61b41&amp;fccid=ea25315ee9da22e5" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[7],true,0);" onmousedown="return rclk(this,jobmap[7],0);" rel="nofollow" target="_blank" title="Data Scientist">
#    <b>
#     Data
#    </b>
#    <b>
#     Scientist
#    </b>
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    <a href="/cmp/Comcast?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=5b4cfc8994a61b41&amp;jcid=ea25315ee9da22e5" target="_blank">
#     Comcast
#    </a>
#   </span>
#  </span>
#  -
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Comcast/reviews?jcid=ea25315ee9da22e5" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist&amp;fromjk=5b4cfc8994a61b41');" target="_blank" title="Comcast reviews">
#   <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;">
#    <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 43.8px;">
#     <!-- -->
#    </span>
#   </span>
#   <span class="slNoUnderline">
#    5,987 reviews
#   </span>
#  </a>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       Visible World is the leading provider of targeted TV advertising solutions. Our technology makes television advertising inventory more valuable for inventory
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="date">
#        5 days ago
#       </span>
#       <span class="tt_set" id="tt_set_7">
#        -
#        <span class="savelink2" id="savelink2_5b4cfc8994a61b41">
#         <a class="sl resultLink save-job-link" href="#" id="sj_5b4cfc8994a61b41" onclick="changeJobState('5b4cfc8994a61b41', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('5b4cfc8994a61b41', 7, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_7" onclick="toggleMoreLinks('5b4cfc8994a61b41'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_5b4cfc8994a61b41" style="display:none;">
#       </div>
#       <script>
#        window['result_5b4cfc8994a61b41'] = {"showSource": false, "source": "Comcast", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "5 days ago","jobKey": "5b4cfc8994a61b41", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 7, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_7" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('5b4cfc8994a61b41'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_7">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-Comcast-l-New-York,-NY-jobs.html" rel="nofollow">
#            Comcast jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">
#            Data Scientist salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Learn more about working at
#           <a href="/cmp/Comcast?fromjk=5b4cfc8994a61b41&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=ea25315ee9da22e5">
#            Comcast
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#           -
#           <a href="/forum/cmp/Comcast.html">
#            Comcast
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# <div class=" row result" data-jk="30c228790352e62c" data-tn-component="organicJob" id="p_30c228790352e62c" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_30c228790352e62c">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=30c228790352e62c&amp;fccid=c63a4b95712b07d4" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[8],true,0);" onmousedown="return rclk(this,jobmap[8],0);" rel="nofollow" target="_blank" title="Data Scientist">
#    <b>
#     Data
#    </b>
#    <b>
#     Scientist
#    </b>
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    Tapad
#   </span>
#  </span>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       Tapad is looking for an experienced
#       <b>
#        Data
#       </b>
#       <b>
#        Scientist
#       </b>
#       to join our Engineering team. The
#       <b>
#        Data
#       </b>
#       <b>
#        Scientist
#       </b>
#       will work on expanding and developing the core of our...
#      </span>
#     </div>
#     <div class="iaP">
#      <span class="iaLabel">
#       Easily apply
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="date">
#        8 days ago
#       </span>
#       <span class="tt_set" id="tt_set_8">
#        -
#        <span class="savelink2" id="savelink2_30c228790352e62c">
#         <a class="sl resultLink save-job-link" href="#" id="sj_30c228790352e62c" onclick="changeJobState('30c228790352e62c', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('30c228790352e62c', 8, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_8" onclick="toggleMoreLinks('30c228790352e62c'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_30c228790352e62c" style="display:none;">
#       </div>
#       <script>
#        window['result_30c228790352e62c'] = {"showSource": false, "source": "Tapad", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "8 days ago","jobKey": "30c228790352e62c", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 8, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_8" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('30c228790352e62c'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_8">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-Tapad-l-New-York,-NY-jobs.html" rel="nofollow">
#            Tapad jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">
#            Data Scientist salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#           -
#           <a href="/forum/cmp/Tapad.html">
#            Tapad
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# []

# %% [markdown]
# Now, to scale up our scraping, we need to accumulate more results. We can do this by examining the URL above.
#
# - "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"
#
# There are two query parameters here we can alter to collect more results, the `l=New+York` and the `start=10`. The first controls the location of the results (so we can try a different city). The second controls where in the results to start and gives 10 results (thus, we can keep incrementing by 10 to go further in the list).

# %% [markdown]
# #### Complete the following code to collect results from multiple cities and starting points.
# - Enter your city below to add it to the search
# - Remember to convert your salary to U.S. Dollars to match the other cities if the currency is different

# %%
url_template = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={}&start={}"
max_results_per_city = 100

results = []

for city in set(['New+York', 'Chicago', 'San+Francisco', 'Austin', YOUR_CITY]):
    for start in range(0, max_results_per_city, 10):
        # Grab the results from the request (as above)
        # Append to the full set of results
        pass

# %% [markdown]
# #### Use the functions you wrote above to parse out the 4 fields - location, title, company and salary. Create a dataframe from the results with those 4 columns.

# %%
## YOUR CODE HERE

# %% [markdown]
# Lastly, we need to clean up salary data.
# 1. Some of the salaries are not yearly but hourly, these will be useful to us for now
# 2. The salaries are given as text and usually with ranges.
#
# #### Filter out the salaries that are not yearly (filter those that refer to hour)

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Write a function that takes a salary string and converts it to a number, averaging a salary range if necessary

# %%
## YOUR CODE HERE

# %% [markdown]
# ### Save your results as a CSV

# %%
## YOUR CODE HERE

# %% [markdown]
# ## Predicting salaries using Logistic Regression

# %% [markdown]
# #### Load in the the data of scraped salaries

# %%
## YOUR CODE HERE

# %% [markdown]
# #### We want to predict a binary variable - whether the salary was low or high. Compute the median salary and create a new binary variable that is true when the salary is high (above the median)

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Thought experiment: What is the baseline accuracy for this model?

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Create a Logistic Regression model to predict High/Low salary using statsmodel. Start by ONLY using the location as a feature. Display the coefficients and write a short summary of what they mean.

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Create a few new variables in your dataframe to represent interesting features of a job title.
# - For example, create a feature that represents whether 'Senior' is in the title
# - or whether 'Manager' is in the title.
# - Then build a new Logistic Regression model with these features. Do they add any value?

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Rebuild this model with scikit-learn.
# - You can either create the dummy features manually or use the `dmatrix` function from `patsy`
# - Remember to scale the feature variables as well!

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Use cross-validation in scikit-learn to evaluate the model above.
# - Evaluate the accuracy, AUC, precision and recall of the model.
# - Discuss the differences and explain when you want a high-recall or a high-precision model in this scenario.

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Compare L1 and L2 regularization for this logistic regression model. What effect does this have on the coefficients learned?

# %%
## YOUR CODE HERE

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Continue to incorporate other text features from the title or summary that you believe will predict the salary and examine their coefficients

# %% [markdown]
# #### Take ~100 scraped entries with salaries. Convert them to use with your model and predict the salary - which entries have the highest predicted salaries?

# %% [markdown]
# ### BONUS

# %% [markdown]
# #### Bonus: Use Count Vectorizer from scikit-learn to create features from the text summaries.
# - Examine using count or binary features in the model
# - Re-evaluate the logistic regression model using these. Does this improve the model performance?
# - What text features are the most valuable?

# %%
## YOUR CODE HERE

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Re-test L1 and L2 regularization. You can use LogisticRegressionCV to find the optimal reguarlization parameters.
# - Re-test what text features are most valuable.
# - How do L1 and L2 change the coefficients?

# %%
## YOUR CODE HERE
