# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
# %matplotlib notebook

# %%
df = pd.DataFrame(np.random.randn(10,4), columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.063081  2.500515 -0.004646 -1.393173
# 1 -0.298888  0.222171 -1.442004 -2.331850
# 2 -2.038512  0.668280 -0.651869  0.244650
# 3 -0.722553 -1.336386  0.875576  0.695077
# 4  0.870417  1.079783 -0.317235  1.089764
# 5  1.287851  0.772014 -0.962964  0.875892
# 6  0.844804  0.711537  0.170985 -0.808519
# 7  0.798355  0.364985  2.640538 -0.412844
# 8  0.055818  0.706371  1.797526  0.107830
# 9  0.492441 -0.520954  0.251407 -0.341342

# %%
df.plot.bar()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
df.plot.scatter(x='a',y='b',color='g',s=500,legend='ss')
# Out:
# <img src="data:image/png;base64,...">
